# %%
import os
from scapy.all import PcapReader, wrpcap

# Directional malicious IP addresses (Source and Destination must match)
directional_botnet_ips = {
    'IRC': [
        ('192.168.2.112', '131.202.243.84'),
        ('192.168.5.122', '198.164.30.2'),
        ('192.168.2.110', '192.168.5.122'),
        ('192.168.4.118', '192.168.5.122'),
        ('192.168.2.113', '192.168.5.122'),
        ('192.168.1.103', '192.168.5.122'),
        ('192.168.4.120', '192.168.5.122'),
        ('192.168.2.112', '192.168.2.110'),
        ('192.168.2.112', '192.168.4.120'),
        ('192.168.2.112', '192.168.1.103'),
        ('192.168.2.112', '192.168.2.113'),
        ('192.168.2.112', '192.168.4.118'),
        ('192.168.2.112', '192.168.2.109'),
        ('192.168.2.112', '192.168.2.105'),
        ('192.168.1.105', '192.168.5.122')
    ]
}

# Non-directional malicious IP addresses (Either Source or Destination matches)
non_directional_botnet_ips = {
    'Neris': ['147.32.84.180'],
    'RBot': ['147.32.84.170'],
    'Menti': ['147.32.84.150'],
    'Sogou': ['147.32.84.140'],
    'Murlo': ['147.32.84.130'],
    'Virut': ['147.32.84.160'],
    'IRCbot_and_black_hole1': ['10.0.2.15'],
    'Black_hole_2': ['192.168.106.141'],
    'Black_hole_3': ['192.168.106.131'],
    'TBot': ['172.16.253.130', '172.16.253.131', '172.16.253.129', '172.16.253.240'],
    'Weasel': ['74.78.117.238', '158.65.110.24'],
    'Zeus': ['192.168.3.35', '192.168.3.25', '192.168.3.65', '172.29.0.116'],
    'Osx_trojan': ['172.29.0.109'],
    'Zero_access': ['172.16.253.132', '192.168.248.165'],
    'Smoke_bot': ['10.37.130.4']
}

# Function to check if packet is malicious and identify its botnet type
def get_botnet_type(packet):
    if packet.haslayer('IP'):
        src_ip = packet['IP'].src
        dst_ip = packet['IP'].dst
        # Check directional botnet IPs
        for botnet, ip_pairs in directional_botnet_ips.items():
            for src, dst in ip_pairs:
                if src_ip == src and dst_ip == dst:
                    return botnet
        # Check non-directional botnet IPs
        for botnet, ips in non_directional_botnet_ips.items():
            if src_ip in ips or dst_ip in ips:
                return botnet
    return None

# Function to clean directories
def clean_directories(dirs):
    for dir in dirs:
        for file in os.listdir(dir):
            file_path = os.path.join(dir, file)
            try:
                if os.path.isfile(file_path):
                    os.unlink(file_path)
            except Exception as e:
                print(f"Error: {e}")

pcap_path = "../pcap/train"
# Create directories for malicious and benign packets
os.makedirs(f'{pcap_path}/malicious', exist_ok=True)
os.makedirs(f'{pcap_path}/benign', exist_ok=True)
clean_directories([f'{pcap_path}/malicious', f'{pcap_path}/benign'])

# Initialize packet storage
malicious_packets = {botnet: [] for botnet in {**directional_botnet_ips, **non_directional_botnet_ips}.keys()}
benign_packets = []

# Function to dump packets to files
def dump_packets():
    for botnet, pkt_list in malicious_packets.items():
        if pkt_list:
            file_name = f'{pcap_path}/malicious/{botnet}.pcap'
            wrpcap(file_name, pkt_list, append=True)
            malicious_packets[botnet] = []  # Reset list after dumping

    if benign_packets:
        wrpcap(f'{pcap_path}/benign/benign.pcap', benign_packets, append=True)
        benign_packets.clear()  # Reset list after dumping

# Read and process packets in chunks
chunk_size = 10000
packet_count = 0

with PcapReader(f'{pcap_path}/input.pcap') as pcap_reader:
    while True:
        packets = pcap_reader.read_all(count=chunk_size)
        if not packets:
            break

        for packet in packets:
            packet_count += 1
            botnet_type = get_botnet_type(packet)
            if botnet_type:
                malicious_packets[botnet_type].append(packet)
            else:
                benign_packets.append(packet)

        # Dump packets after each chunk
        dump_packets()
        print(f"Processed {packet_count} packets so far...")

# Final dump to ensure all packets are written
dump_packets()

print(f"Processed {packet_count} packets in total.")
# Out:
# Processed 10000 packets so far...
# Processed 20000 packets so far...
# Processed 30000 packets so far...
# Processed 40000 packets so far...
# Processed 50000 packets so far...
# Processed 60000 packets so far...
# Processed 70000 packets so far...
# Processed 80000 packets so far...
# Processed 90000 packets so far...
# Processed 100000 packets so far...
# Processed 110000 packets so far...
# Processed 120000 packets so far...
# Processed 130000 packets so far...
# Processed 140000 packets so far...
# Processed 150000 packets so far...
# Processed 160000 packets so far...
# Processed 170000 packets so far...
# Processed 180000 packets so far...
# Processed 190000 packets so far...
# Processed 200000 packets so far...
# Processed 210000 packets so far...
# Processed 220000 packets so far...
# Processed 230000 packets so far...
# Processed 240000 packets so far...
# Processed 250000 packets so far...
# Processed 260000 packets so far...
# Processed 270000 packets so far...
# Processed 280000 packets so far...
# Processed 290000 packets so far...
# Processed 300000 packets so far...
# Processed 310000 packets so far...
# Processed 320000 packets so far...
# Processed 330000 packets so far...
# Processed 340000 packets so far...
# Processed 350000 packets so far...
# Processed 360000 packets so far...
# Processed 370000 packets so far...
# Processed 380000 packets so far...
# Processed 390000 packets so far...
# Processed 400000 packets so far...
# Processed 410000 packets so far...
# Processed 420000 packets so far...
# Processed 430000 packets so far...
# Processed 440000 packets so far...
# Processed 450000 packets so far...
# Processed 460000 packets so far...
# Processed 470000 packets so far...
# Processed 480000 packets so far...
# Processed 490000 packets so far...
# Processed 500000 packets so far...
# Processed 510000 packets so far...
# Processed 520000 packets so far...
# Processed 530000 packets so far...
# Processed 540000 packets so far...
# Processed 550000 packets so far...
# Processed 560000 packets so far...
# Processed 570000 packets so far...
# Processed 580000 packets so far...
# Processed 590000 packets so far...
# Processed 600000 packets so far...
# Processed 610000 packets so far...
# Processed 620000 packets so far...
# Processed 630000 packets so far...
# Processed 640000 packets so far...
# Processed 650000 packets so far...
# Processed 660000 packets so far...
# Processed 670000 packets so far...
# Processed 680000 packets so far...
# Processed 690000 packets so far...
# Processed 700000 packets so far...
# Processed 710000 packets so far...
# Processed 720000 packets so far...
# Processed 730000 packets so far...
# Processed 740000 packets so far...
# Processed 750000 packets so far...
# Processed 760000 packets so far...
# Processed 770000 packets so far...
# Processed 780000 packets so far...
# Processed 790000 packets so far...
# Processed 800000 packets so far...
# Processed 810000 packets so far...
# Processed 820000 packets so far...
# Processed 830000 packets so far...
# Processed 840000 packets so far...
# Processed 850000 packets so far...
# Processed 860000 packets so far...
# Processed 870000 packets so far...
# Processed 880000 packets so far...
# Processed 890000 packets so far...
# Processed 900000 packets so far...
# Processed 910000 packets so far...
# Processed 920000 packets so far...
# Processed 930000 packets so far...
# Processed 940000 packets so far...
# Processed 950000 packets so far...
# Processed 960000 packets so far...
# Processed 970000 packets so far...
# Processed 980000 packets so far...
# Processed 990000 packets so far...
# Processed 1000000 packets so far...
# Processed 1010000 packets so far...
# Processed 1020000 packets so far...
# Processed 1030000 packets so far...
# Processed 1040000 packets so far...
# Processed 1050000 packets so far...
# Processed 1060000 packets so far...
# Processed 1070000 packets so far...
# Processed 1080000 packets so far...
# Processed 1090000 packets so far...
# Processed 1100000 packets so far...
# Processed 1110000 packets so far...
# Processed 1120000 packets so far...
# Processed 1130000 packets so far...
# Processed 1140000 packets so far...
# Processed 1150000 packets so far...
# Processed 1160000 packets so far...
# Processed 1170000 packets so far...
# Processed 1180000 packets so far...
# Processed 1190000 packets so far...
# Processed 1200000 packets so far...
# Processed 1210000 packets so far...
# Processed 1220000 packets so far...
# Processed 1230000 packets so far...
# Processed 1240000 packets so far...
# Processed 1250000 packets so far...
# Processed 1260000 packets so far...
# Processed 1270000 packets so far...
# Processed 1280000 packets so far...
# Processed 1290000 packets so far...
# Processed 1300000 packets so far...
# Processed 1310000 packets so far...
# Processed 1320000 packets so far...
# Processed 1330000 packets so far...
# Processed 1340000 packets so far...
# Processed 1350000 packets so far...
# Processed 1360000 packets so far...
# Processed 1370000 packets so far...
# Processed 1380000 packets so far...
# Processed 1390000 packets so far...
# Processed 1400000 packets so far...
# Processed 1410000 packets so far...
# Processed 1420000 packets so far...
# Processed 1430000 packets so far...
# Processed 1440000 packets so far...
# Processed 1450000 packets so far...
# Processed 1460000 packets so far...
# Processed 1470000 packets so far...
# Processed 1480000 packets so far...
# Processed 1490000 packets so far...
# Processed 1500000 packets so far...
# Processed 1510000 packets so far...
# Processed 1520000 packets so far...
# Processed 1530000 packets so far...
# Processed 1540000 packets so far...
# Processed 1550000 packets so far...
# Processed 1560000 packets so far...
# Processed 1570000 packets so far...
# Processed 1580000 packets so far...
# Processed 1590000 packets so far...
# Processed 1600000 packets so far...
# Processed 1610000 packets so far...
# Processed 1620000 packets so far...
# Processed 1630000 packets so far...
# Processed 1640000 packets so far...
# Processed 1650000 packets so far...
# Processed 1660000 packets so far...
# Processed 1670000 packets so far...
# Processed 1680000 packets so far...
# Processed 1690000 packets so far...
# Processed 1700000 packets so far...
# Processed 1710000 packets so far...
# Processed 1720000 packets so far...
# Processed 1730000 packets so far...
# Processed 1740000 packets so far...
# Processed 1750000 packets so far...
# Processed 1760000 packets so far...
# Processed 1770000 packets so far...
# Processed 1780000 packets so far...
# Processed 1790000 packets so far...
# Processed 1800000 packets so far...
# Processed 1810000 packets so far...
# Processed 1820000 packets so far...
# Processed 1830000 packets so far...
# Processed 1840000 packets so far...
# Processed 1850000 packets so far...
# Processed 1860000 packets so far...
# Processed 1870000 packets so far...
# Processed 1880000 packets so far...
# Processed 1890000 packets so far...
# Processed 1900000 packets so far...
# Processed 1910000 packets so far...
# Processed 1920000 packets so far...
# Processed 1930000 packets so far...
# Processed 1940000 packets so far...
# Processed 1950000 packets so far...
# Processed 1960000 packets so far...
# Processed 1970000 packets so far...
# Processed 1980000 packets so far...
# Processed 1990000 packets so far...
# Processed 2000000 packets so far...
# Processed 2010000 packets so far...
# Processed 2020000 packets so far...
# Processed 2030000 packets so far...
# Processed 2040000 packets so far...
# Processed 2050000 packets so far...
# Processed 2060000 packets so far...
# Processed 2070000 packets so far...
# Processed 2080000 packets so far...
# Processed 2090000 packets so far...
# Processed 2100000 packets so far...
# Processed 2110000 packets so far...
# Processed 2120000 packets so far...
# Processed 2130000 packets so far...
# Processed 2140000 packets so far...
# Processed 2150000 packets so far...
# Processed 2160000 packets so far...
# Processed 2170000 packets so far...
# Processed 2180000 packets so far...
# Processed 2190000 packets so far...
# Processed 2200000 packets so far...
# Processed 2210000 packets so far...
# Processed 2220000 packets so far...
# Processed 2230000 packets so far...
# Processed 2240000 packets so far...
# Processed 2250000 packets so far...
# Processed 2260000 packets so far...
# Processed 2270000 packets so far...
# Processed 2280000 packets so far...
# Processed 2290000 packets so far...
# Processed 2300000 packets so far...
# Processed 2310000 packets so far...
# Processed 2320000 packets so far...
# Processed 2330000 packets so far...
# Processed 2340000 packets so far...
# Processed 2350000 packets so far...
# Processed 2360000 packets so far...
# Processed 2370000 packets so far...
# Processed 2380000 packets so far...
# Processed 2390000 packets so far...
# Processed 2400000 packets so far...
# Processed 2410000 packets so far...
# Processed 2420000 packets so far...
# Processed 2430000 packets so far...
# Processed 2440000 packets so far...
# Processed 2450000 packets so far...
# Processed 2460000 packets so far...
# Processed 2470000 packets so far...
# Processed 2480000 packets so far...
# Processed 2490000 packets so far...
# Processed 2500000 packets so far...
# Processed 2510000 packets so far...
# Processed 2520000 packets so far...
# Processed 2530000 packets so far...
# Processed 2540000 packets so far...
# Processed 2550000 packets so far...
# Processed 2560000 packets so far...
# Processed 2570000 packets so far...
# Processed 2580000 packets so far...
# Processed 2590000 packets so far...
# Processed 2600000 packets so far...
# Processed 2610000 packets so far...
# Processed 2620000 packets so far...
# Processed 2630000 packets so far...
# Processed 2640000 packets so far...
# Processed 2650000 packets so far...
# Processed 2660000 packets so far...
# Processed 2670000 packets so far...
# Processed 2680000 packets so far...
# Processed 2690000 packets so far...
# Processed 2700000 packets so far...
# Processed 2710000 packets so far...
# Processed 2720000 packets so far...
# Processed 2730000 packets so far...
# Processed 2740000 packets so far...
# Processed 2750000 packets so far...
# Processed 2760000 packets so far...
# Processed 2770000 packets so far...
# Processed 2780000 packets so far...
# Processed 2790000 packets so far...
# Processed 2800000 packets so far...
# Processed 2810000 packets so far...
# Processed 2820000 packets so far...
# Processed 2830000 packets so far...
# Processed 2840000 packets so far...
# Processed 2850000 packets so far...
# Processed 2860000 packets so far...
# Processed 2870000 packets so far...
# Processed 2880000 packets so far...
# Processed 2890000 packets so far...
# Processed 2900000 packets so far...
# Processed 2910000 packets so far...
# Processed 2920000 packets so far...
# Processed 2930000 packets so far...
# Processed 2940000 packets so far...
# Processed 2950000 packets so far...
# Processed 2960000 packets so far...
# Processed 2970000 packets so far...
# Processed 2980000 packets so far...
# Processed 2990000 packets so far...
# Processed 3000000 packets so far...
# Processed 3010000 packets so far...
# Processed 3020000 packets so far...
# Processed 3030000 packets so far...
# Processed 3040000 packets so far...
# Processed 3050000 packets so far...
# Processed 3060000 packets so far...
# Processed 3070000 packets so far...
# Processed 3080000 packets so far...
# Processed 3090000 packets so far...
# Processed 3100000 packets so far...
# Processed 3110000 packets so far...
# Processed 3120000 packets so far...
# Processed 3130000 packets so far...
# Processed 3140000 packets so far...
# Processed 3150000 packets so far...
# Processed 3160000 packets so far...
# Processed 3170000 packets so far...
# Processed 3180000 packets so far...
# Processed 3190000 packets so far...
# Processed 3200000 packets so far...
# Processed 3210000 packets so far...
# Processed 3220000 packets so far...
# Processed 3230000 packets so far...
# Processed 3240000 packets so far...
# Processed 3250000 packets so far...
# Processed 3260000 packets so far...
# Processed 3270000 packets so far...
# Processed 3280000 packets so far...
# Processed 3290000 packets so far...
# Processed 3300000 packets so far...
# Processed 3310000 packets so far...
# Processed 3320000 packets so far...
# Processed 3330000 packets so far...
# Processed 3340000 packets so far...
# Processed 3350000 packets so far...
# Processed 3360000 packets so far...
# Processed 3370000 packets so far...
# Processed 3380000 packets so far...
# Processed 3390000 packets so far...
# Processed 3400000 packets so far...
# Processed 3410000 packets so far...
# Processed 3420000 packets so far...
# Processed 3430000 packets so far...
# Processed 3440000 packets so far...
# Processed 3450000 packets so far...
# Processed 3460000 packets so far...
# Processed 3470000 packets so far...
# Processed 3480000 packets so far...
# Processed 3490000 packets so far...
# Processed 3500000 packets so far...
# Processed 3510000 packets so far...
# Processed 3520000 packets so far...
# Processed 3530000 packets so far...
# Processed 3540000 packets so far...
# Processed 3550000 packets so far...
# Processed 3560000 packets so far...
# Processed 3570000 packets so far...
# Processed 3580000 packets so far...
# Processed 3590000 packets so far...
# Processed 3600000 packets so far...
# Processed 3610000 packets so far...
# Processed 3620000 packets so far...
# Processed 3630000 packets so far...
# Processed 3640000 packets so far...
# Processed 3650000 packets so far...
# Processed 3660000 packets so far...
# Processed 3670000 packets so far...
# Processed 3680000 packets so far...
# Processed 3690000 packets so far...
# Processed 3700000 packets so far...
# Processed 3710000 packets so far...
# Processed 3720000 packets so far...
# Processed 3730000 packets so far...
# Processed 3740000 packets so far...
# Processed 3750000 packets so far...
# Processed 3760000 packets so far...
# Processed 3770000 packets so far...
# Processed 3780000 packets so far...
# Processed 3790000 packets so far...
# Processed 3800000 packets so far...
# Processed 3810000 packets so far...
# Processed 3820000 packets so far...
# Processed 3830000 packets so far...
# Processed 3840000 packets so far...
# Processed 3850000 packets so far...
# Processed 3860000 packets so far...
# Processed 3870000 packets so far...
# Processed 3880000 packets so far...
# Processed 3890000 packets so far...
# Processed 3900000 packets so far...
# Processed 3910000 packets so far...
# Processed 3920000 packets so far...
# Processed 3930000 packets so far...
# Processed 3940000 packets so far...
# Processed 3950000 packets so far...
# Processed 3960000 packets so far...
# Processed 3970000 packets so far...
# Processed 3980000 packets so far...
# Processed 3990000 packets so far...
# Processed 4000000 packets so far...
# Processed 4010000 packets so far...
# Processed 4020000 packets so far...
# Processed 4030000 packets so far...
# Processed 4040000 packets so far...
# Processed 4050000 packets so far...
# Processed 4060000 packets so far...
# Processed 4070000 packets so far...
# Processed 4080000 packets so far...
# Processed 4090000 packets so far...
# Processed 4100000 packets so far...
# Processed 4110000 packets so far...
# Processed 4120000 packets so far...
# Processed 4130000 packets so far...
# Processed 4140000 packets so far...
# Processed 4150000 packets so far...
# Processed 4160000 packets so far...
# Processed 4170000 packets so far...
# Processed 4180000 packets so far...
# Processed 4190000 packets so far...
# Processed 4200000 packets so far...
# Processed 4210000 packets so far...
# Processed 4220000 packets so far...
# Processed 4230000 packets so far...
# Processed 4240000 packets so far...
# Processed 4250000 packets so far...
# Processed 4260000 packets so far...
# Processed 4270000 packets so far...
# Processed 4280000 packets so far...
# Processed 4290000 packets so far...
# Processed 4300000 packets so far...
# Processed 4310000 packets so far...
# Processed 4320000 packets so far...
# Processed 4330000 packets so far...
# Processed 4340000 packets so far...
# Processed 4350000 packets so far...
# Processed 4360000 packets so far...
# Processed 4370000 packets so far...
# Processed 4380000 packets so far...
# Processed 4390000 packets so far...
# Processed 4400000 packets so far...
# Processed 4410000 packets so far...
# Processed 4420000 packets so far...
# Processed 4430000 packets so far...
# Processed 4440000 packets so far...
# Processed 4450000 packets so far...
# Processed 4460000 packets so far...
# Processed 4470000 packets so far...
# Processed 4480000 packets so far...
# Processed 4490000 packets so far...
# Processed 4500000 packets so far...
# Processed 4510000 packets so far...
# Processed 4520000 packets so far...
# Processed 4530000 packets so far...
# Processed 4540000 packets so far...
# Processed 4550000 packets so far...
# Processed 4560000 packets so far...
# Processed 4570000 packets so far...
# Processed 4580000 packets so far...
# Processed 4590000 packets so far...
# Processed 4600000 packets so far...
# Processed 4610000 packets so far...
# Processed 4620000 packets so far...
# Processed 4630000 packets so far...
# Processed 4640000 packets so far...
# Processed 4650000 packets so far...
# Processed 4660000 packets so far...
# Processed 4670000 packets so far...
# Processed 4680000 packets so far...
# Processed 4690000 packets so far...
# Processed 4700000 packets so far...
# Processed 4710000 packets so far...
# Processed 4720000 packets so far...
# Processed 4730000 packets so far...
# Processed 4740000 packets so far...
# Processed 4750000 packets so far...
# Processed 4760000 packets so far...
# Processed 4770000 packets so far...
# Processed 4780000 packets so far...
# Processed 4790000 packets so far...
# Processed 4800000 packets so far...
# Processed 4810000 packets so far...
# Processed 4820000 packets so far...
# Processed 4830000 packets so far...
# Processed 4840000 packets so far...
# Processed 4850000 packets so far...
# Processed 4860000 packets so far...
# Processed 4870000 packets so far...
# Processed 4880000 packets so far...
# Processed 4890000 packets so far...
# Processed 4900000 packets so far...
# Processed 4910000 packets so far...
# Processed 4920000 packets so far...
# Processed 4930000 packets so far...
# Processed 4940000 packets so far...
# Processed 4950000 packets so far...
# Processed 4960000 packets so far...
# Processed 4970000 packets so far...
# Processed 4980000 packets so far...
# Processed 4990000 packets so far...
# Processed 5000000 packets so far...
# Processed 5010000 packets so far...
# Processed 5020000 packets so far...
# Processed 5030000 packets so far...
# Processed 5040000 packets so far...
# Processed 5050000 packets so far...
# Processed 5060000 packets so far...
# Processed 5070000 packets so far...
# Processed 5080000 packets so far...
# Processed 5090000 packets so far...
# Processed 5100000 packets so far...
# Processed 5110000 packets so far...
# Processed 5120000 packets so far...
# Processed 5130000 packets so far...
# Processed 5140000 packets so far...
# Processed 5150000 packets so far...
# Processed 5160000 packets so far...
# Processed 5170000 packets so far...
# Processed 5180000 packets so far...
# Processed 5190000 packets so far...
# Processed 5200000 packets so far...
# Processed 5210000 packets so far...
# Processed 5220000 packets so far...
# Processed 5230000 packets so far...
# Processed 5240000 packets so far...
# Processed 5250000 packets so far...
# Processed 5260000 packets so far...
# Processed 5270000 packets so far...
# Processed 5280000 packets so far...
# Processed 5290000 packets so far...
# Processed 5300000 packets so far...
# Processed 5310000 packets so far...
# Processed 5320000 packets so far...
# Processed 5330000 packets so far...
# Processed 5340000 packets so far...
# Processed 5350000 packets so far...
# Processed 5360000 packets so far...
# Processed 5370000 packets so far...
# Processed 5380000 packets so far...
# Processed 5390000 packets so far...
# Processed 5400000 packets so far...
# Processed 5410000 packets so far...
# Processed 5420000 packets so far...
# Processed 5430000 packets so far...
# Processed 5440000 packets so far...
# Processed 5450000 packets so far...
# Processed 5460000 packets so far...
# Processed 5470000 packets so far...
# Processed 5480000 packets so far...
# Processed 5490000 packets so far...
# Processed 5500000 packets so far...
# Processed 5510000 packets so far...
# Processed 5520000 packets so far...
# Processed 5530000 packets so far...
# Processed 5540000 packets so far...
# Processed 5550000 packets so far...
# Processed 5560000 packets so far...
# Processed 5570000 packets so far...
# Processed 5580000 packets so far...
# Processed 5590000 packets so far...
# Processed 5600000 packets so far...
# Processed 5610000 packets so far...
# Processed 5620000 packets so far...
# Processed 5630000 packets so far...
# Processed 5640000 packets so far...
# Processed 5650000 packets so far...
# Processed 5660000 packets so far...
# Processed 5670000 packets so far...
# Processed 5680000 packets so far...
# Processed 5690000 packets so far...
# Processed 5700000 packets so far...
# Processed 5710000 packets so far...
# Processed 5720000 packets so far...
# Processed 5730000 packets so far...
# Processed 5740000 packets so far...
# Processed 5750000 packets so far...
# Processed 5760000 packets so far...
# Processed 5770000 packets so far...
# Processed 5780000 packets so far...
# Processed 5790000 packets so far...
# Processed 5800000 packets so far...
# Processed 5810000 packets so far...
# Processed 5820000 packets so far...
# Processed 5830000 packets so far...
# Processed 5840000 packets so far...
# Processed 5850000 packets so far...
# Processed 5860000 packets so far...
# Processed 5870000 packets so far...
# Processed 5880000 packets so far...
# Processed 5890000 packets so far...
# Processed 5900000 packets so far...
# Processed 5910000 packets so far...
# Processed 5920000 packets so far...
# Processed 5930000 packets so far...
# Processed 5940000 packets so far...
# Processed 5950000 packets so far...
# Processed 5960000 packets so far...
# Processed 5970000 packets so far...
# Processed 5980000 packets so far...
# Processed 5990000 packets so far...
# Processed 6000000 packets so far...
# Processed 6010000 packets so far...
# Processed 6020000 packets so far...
# Processed 6030000 packets so far...
# Processed 6040000 packets so far...
# Processed 6050000 packets so far...
# Processed 6060000 packets so far...
# Processed 6070000 packets so far...
# Processed 6080000 packets so far...
# Processed 6090000 packets so far...
# Processed 6100000 packets so far...
# Processed 6110000 packets so far...
# Processed 6120000 packets so far...
# Processed 6130000 packets so far...
# Processed 6140000 packets so far...
# Processed 6150000 packets so far...
# Processed 6160000 packets so far...
# Processed 6170000 packets so far...
# Processed 6180000 packets so far...
# Processed 6190000 packets so far...
# Processed 6200000 packets so far...
# Processed 6210000 packets so far...
# Processed 6220000 packets so far...
# Processed 6230000 packets so far...
# Processed 6240000 packets so far...
# Processed 6250000 packets so far...
# Processed 6260000 packets so far...
# Processed 6270000 packets so far...
# Processed 6280000 packets so far...
# Processed 6290000 packets so far...
# Processed 6300000 packets so far...
# Processed 6310000 packets so far...
# Processed 6320000 packets so far...
# Processed 6330000 packets so far...
# Processed 6340000 packets so far...
# Processed 6350000 packets so far...
# Processed 6360000 packets so far...
# Processed 6370000 packets so far...
# Processed 6380000 packets so far...
# Processed 6390000 packets so far...
# Processed 6400000 packets so far...
# Processed 6410000 packets so far...
# Processed 6420000 packets so far...
# Processed 6430000 packets so far...
# Processed 6440000 packets so far...
# Processed 6450000 packets so far...
# Processed 6460000 packets so far...
# Processed 6470000 packets so far...
# Processed 6480000 packets so far...
# Processed 6490000 packets so far...
# Processed 6500000 packets so far...
# Processed 6510000 packets so far...
# Processed 6520000 packets so far...
# Processed 6530000 packets so far...
# Processed 6540000 packets so far...
# Processed 6550000 packets so far...
# Processed 6560000 packets so far...
# Processed 6570000 packets so far...
# Processed 6580000 packets so far...
# Processed 6590000 packets so far...
# Processed 6600000 packets so far...
# Processed 6610000 packets so far...
# Processed 6620000 packets so far...
# Processed 6630000 packets so far...
# Processed 6640000 packets so far...
# Processed 6650000 packets so far...
# Processed 6660000 packets so far...
# Processed 6670000 packets so far...
# Processed 6680000 packets so far...
# Processed 6690000 packets so far...
# Processed 6700000 packets so far...
# Processed 6710000 packets so far...
# Processed 6720000 packets so far...
# Processed 6730000 packets so far...
# Processed 6740000 packets so far...
# Processed 6750000 packets so far...
# Processed 6760000 packets so far...
# Processed 6770000 packets so far...
# Processed 6780000 packets so far...
# Processed 6790000 packets so far...
# Processed 6800000 packets so far...
# Processed 6810000 packets so far...
# Processed 6820000 packets so far...
# Processed 6830000 packets so far...
# Processed 6840000 packets so far...
# Processed 6850000 packets so far...
# Processed 6860000 packets so far...
# Processed 6870000 packets so far...
# Processed 6880000 packets so far...
# Processed 6890000 packets so far...
# Processed 6900000 packets so far...
# Processed 6910000 packets so far...
# Processed 6920000 packets so far...
# Processed 6930000 packets so far...
# Processed 6940000 packets so far...
# Processed 6950000 packets so far...
# Processed 6960000 packets so far...
# Processed 6970000 packets so far...
# Processed 6980000 packets so far...
# Processed 6990000 packets so far...
# Processed 7000000 packets so far...
# Processed 7010000 packets so far...
# Processed 7020000 packets so far...
# Processed 7030000 packets so far...
# Processed 7040000 packets so far...
# Processed 7050000 packets so far...
# Processed 7060000 packets so far...
# Processed 7070000 packets so far...
# Processed 7080000 packets so far...
# Processed 7090000 packets so far...
# Processed 7100000 packets so far...
# Processed 7110000 packets so far...
# Processed 7120000 packets so far...
# Processed 7130000 packets so far...
# Processed 7140000 packets so far...
# Processed 7150000 packets so far...
# Processed 7160000 packets so far...
# Processed 7170000 packets so far...
# Processed 7180000 packets so far...
# Processed 7190000 packets so far...
# Processed 7200000 packets so far...
# Processed 7210000 packets so far...
# Processed 7220000 packets so far...
# Processed 7230000 packets so far...
# Processed 7240000 packets so far...
# Processed 7250000 packets so far...
# Processed 7260000 packets so far...
# Processed 7270000 packets so far...
# Processed 7280000 packets so far...
# Processed 7290000 packets so far...
# Processed 7300000 packets so far...
# Processed 7310000 packets so far...
# Processed 7320000 packets so far...
# Processed 7330000 packets so far...
# Processed 7340000 packets so far...
# Processed 7350000 packets so far...
# Processed 7360000 packets so far...
# Processed 7370000 packets so far...
# Processed 7380000 packets so far...
# Processed 7390000 packets so far...
# Processed 7400000 packets so far...
# Processed 7410000 packets so far...
# Processed 7420000 packets so far...
# Processed 7430000 packets so far...
# Processed 7440000 packets so far...
# Processed 7450000 packets so far...
# Processed 7460000 packets so far...
# Processed 7470000 packets so far...
# Processed 7480000 packets so far...
# Processed 7490000 packets so far...
# Processed 7500000 packets so far...
# Processed 7510000 packets so far...
# Processed 7520000 packets so far...
# Processed 7530000 packets so far...
# Processed 7540000 packets so far...
# Processed 7550000 packets so far...
# Processed 7560000 packets so far...
# Processed 7570000 packets so far...
# Processed 7580000 packets so far...
# Processed 7590000 packets so far...
# Processed 7600000 packets so far...
# Processed 7610000 packets so far...
# Processed 7620000 packets so far...
# Processed 7630000 packets so far...
# Processed 7640000 packets so far...
# Processed 7650000 packets so far...
# Processed 7660000 packets so far...
# Processed 7670000 packets so far...
# Processed 7680000 packets so far...
# Processed 7690000 packets so far...
# Processed 7700000 packets so far...
# Processed 7710000 packets so far...
# Processed 7720000 packets so far...
# Processed 7730000 packets so far...
# Processed 7740000 packets so far...
# Processed 7750000 packets so far...
# Processed 7760000 packets so far...
# Processed 7770000 packets so far...
# Processed 7780000 packets so far...
# Processed 7790000 packets so far...
# Processed 7800000 packets so far...
# Processed 7810000 packets so far...
# Processed 7820000 packets so far...
# Processed 7830000 packets so far...
# Processed 7840000 packets so far...
# Processed 7850000 packets so far...
# Processed 7860000 packets so far...
# Processed 7870000 packets so far...
# Processed 7880000 packets so far...
# Processed 7890000 packets so far...
# Processed 7900000 packets so far...
# Processed 7910000 packets so far...
# Processed 7920000 packets so far...
# Processed 7930000 packets so far...
# Processed 7940000 packets so far...
# Processed 7950000 packets so far...
# Processed 7960000 packets so far...
# Processed 7970000 packets so far...
# Processed 7980000 packets so far...
# Processed 7990000 packets so far...
# Processed 8000000 packets so far...
# Processed 8010000 packets so far...
# Processed 8020000 packets so far...
# Processed 8030000 packets so far...
# Processed 8040000 packets so far...
# Processed 8050000 packets so far...
# Processed 8060000 packets so far...
# Processed 8070000 packets so far...
# Processed 8080000 packets so far...
# Processed 8090000 packets so far...
# Processed 8100000 packets so far...
# Processed 8110000 packets so far...
# Processed 8120000 packets so far...
# Processed 8130000 packets so far...
# Processed 8140000 packets so far...
# Processed 8150000 packets so far...
# Processed 8160000 packets so far...
# Processed 8170000 packets so far...
# Processed 8180000 packets so far...
# Processed 8190000 packets so far...
# Processed 8200000 packets so far...
# Processed 8210000 packets so far...
# Processed 8220000 packets so far...
# Processed 8230000 packets so far...
# Processed 8240000 packets so far...
# Processed 8250000 packets so far...
# Processed 8260000 packets so far...
# Processed 8270000 packets so far...
# Processed 8280000 packets so far...
# Processed 8290000 packets so far...
# Processed 8300000 packets so far...
# Processed 8310000 packets so far...
# Processed 8320000 packets so far...
# Processed 8330000 packets so far...
# Processed 8340000 packets so far...
# Processed 8350000 packets so far...
# Processed 8360000 packets so far...
# Processed 8370000 packets so far...
# Processed 8380000 packets so far...
# Processed 8390000 packets so far...
# Processed 8400000 packets so far...
# Processed 8410000 packets so far...
# Processed 8420000 packets so far...
# Processed 8430000 packets so far...
# Processed 8440000 packets so far...
# Processed 8450000 packets so far...
# Processed 8460000 packets so far...
# Processed 8470000 packets so far...
# Processed 8480000 packets so far...
# Processed 8490000 packets so far...
# Processed 8500000 packets so far...
# Processed 8510000 packets so far...
# Processed 8520000 packets so far...
# Processed 8530000 packets so far...
# Processed 8540000 packets so far...
# Processed 8550000 packets so far...
# Processed 8560000 packets so far...
# Processed 8570000 packets so far...
# Processed 8580000 packets so far...
# Processed 8590000 packets so far...
# Processed 8600000 packets so far...
# Processed 8610000 packets so far...
# Processed 8620000 packets so far...
# Processed 8630000 packets so far...
# Processed 8640000 packets so far...
# Processed 8650000 packets so far...
# Processed 8660000 packets so far...
# Processed 8670000 packets so far...
# Processed 8680000 packets so far...
# Processed 8690000 packets so far...
# Processed 8700000 packets so far...
# Processed 8710000 packets so far...
# Processed 8720000 packets so far...
# Processed 8730000 packets so far...
# Processed 8740000 packets so far...
# Processed 8750000 packets so far...
# Processed 8760000 packets so far...
# Processed 8770000 packets so far...
# Processed 8780000 packets so far...
# Processed 8790000 packets so far...
# Processed 8800000 packets so far...
# Processed 8810000 packets so far...
# Processed 8820000 packets so far...
# Processed 8830000 packets so far...
# Processed 8840000 packets so far...
# Processed 8850000 packets so far...
# Processed 8860000 packets so far...
# Processed 8870000 packets so far...
# Processed 8880000 packets so far...
# Processed 8890000 packets so far...
# Processed 8900000 packets so far...
# Processed 8910000 packets so far...
# Processed 8920000 packets so far...
# Processed 8930000 packets so far...
# Processed 8940000 packets so far...
# Processed 8950000 packets so far...
# Processed 8960000 packets so far...
# Processed 8970000 packets so far...
# Processed 8980000 packets so far...
# Processed 8990000 packets so far...
# Processed 9000000 packets so far...
# Processed 9010000 packets so far...
# Processed 9020000 packets so far...
# Processed 9030000 packets so far...
# Processed 9040000 packets so far...
# Processed 9050000 packets so far...
# Processed 9060000 packets so far...
# Processed 9070000 packets so far...
# Processed 9080000 packets so far...
# Processed 9090000 packets so far...
# Processed 9100000 packets so far...
# Processed 9110000 packets so far...
# Processed 9120000 packets so far...
# Processed 9130000 packets so far...
# Processed 9140000 packets so far...
# Processed 9150000 packets so far...
# Processed 9160000 packets so far...
# Processed 9170000 packets so far...
# Processed 9180000 packets so far...
# Processed 9190000 packets so far...
# Processed 9200000 packets so far...
# Processed 9210000 packets so far...
# Processed 9220000 packets so far...
# Processed 9230000 packets so far...
# Processed 9240000 packets so far...
# Processed 9250000 packets so far...
# Processed 9260000 packets so far...
# Processed 9270000 packets so far...
# Processed 9280000 packets so far...
# Processed 9290000 packets so far...
# Processed 9300000 packets so far...
# Processed 9310000 packets so far...
# Processed 9320000 packets so far...
# Processed 9330000 packets so far...
# Processed 9340000 packets so far...
# Processed 9350000 packets so far...
# Processed 9360000 packets so far...
# Processed 9370000 packets so far...
# Processed 9380000 packets so far...
# Processed 9388270 packets so far...
# Processed 9388270 packets in total.
